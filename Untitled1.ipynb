# %% [markdown]
# <a href="https://colab.research.google.com/github/romerofigueroavaleria-dotcom/analysis-everpeak/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importar Pandas y cargar datos
import pandas as pd
df = pd.read_csv('/content/everpeak_retail.csv')
df
# Out:
#       order_id  order_date  customer_id product_category  price  quantity  \
# 0            1  2024-02-02         2616           Sports    269        50
# 1            2  2024-10-10         1736          Grocery     66         0
# 2            3  2024-08-27         2543           Sports    267         0
# 3            4  2024-06-09         2252             Toys    114       125
# 4            5  2024-06-07         1583          Fashion    729        16
# ...        ...         ...          ...              ...    ...       ...
# 5003      5004         NaN         1154          Fashion    368         0
# 5004      5005         NaN         1408      Electronics    687        15
# 5005      5006         NaN         2935             Toys    797         0
# 5006      5007         NaN         2452             Toys    228         0
# 5007      5008         NaN         2509           Sports   1911         0
#
#       order_value payment_method         city state  customer_age
# ...
