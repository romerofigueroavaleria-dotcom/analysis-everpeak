# %% [markdown]
# <a href="https://colab.research.google.com/github/romerofigueroavaleria-dotcom/analysis-everpeak/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
https://colab.research.google.com/assets/colab-badge.svg
# Out:
#   File "/tmp/ipykernel_484/3861370888.py", line 1
#     https://colab.research.google.com/assets/colab-badge.svg
#           ^
# SyntaxError: invalid syntax

# %%
import requests

url = 'https://colab.research.google.com/assets/colab-badge.svg'
file_name = 'colab-badge.svg'

response = requests.get(url)
response.raise_for_status() # Raise an HTTPError for bad responses (4xx or 5xx)

with open(file_name, 'wb') as f:
    f.write(response.content)

print(f'Downloaded {file_name} to your Colab environment.')
# Out:
# Downloaded colab-badge.svg to your Colab environment.

# %% [markdown]
# This code downloads the SVG file and saves it as `colab-badge.svg` in your Colab file system. You can then access it like any other local file.
#
# If your intention was simply to display the image as a badge in your notebook, using a markdown cell with the appropriate image syntax (e.g., `![Alt text](https://colab.research.google.com/assets/colab-badge.svg)`) would be more suitable.
